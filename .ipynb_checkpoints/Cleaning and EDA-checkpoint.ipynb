# %% [markdown]
# ### Data Cleaning

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import re
import seaborn as sb
from collections import Counter
import tqdm
from nltk import word_tokenize, sent_tokenize
from nltk.corpus import stopwords
import unicodedata
from sklearn.feature_extraction.text import TfidfVectorizer
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# %%
express = pd.read_csv('express.csv')
express.head()
# Out:
#                                                  URL  \
# 0  https://tribune.com.pk/story/1813087/6-asad-um...
# 1  https://tribune.com.pk/story/1755479/3-sarah-p...
# 2  https://tribune.com.pk/story/1693045/4-anwar-m...
# 3  https://tribune.com.pk/story/1632147/1-making-...
# 4  https://tribune.com.pk/story/1534757/russian-p...
#
#                                             Headline                    Date1  \
# 0  Asad Umar checks Pakistan into a financial reh...  2018-09-28T03:58:09 GMT
# 1  Sarah Palin tears into 'sick' Baron Cohen over...  2018-07-11T18:37:45 GMT
# 2  Anwar Maqsood’s offensive satire on Sindhis ca...  2018-04-23T09:46:46 GMT
# 3  Making sense of the times: Is reality stranger...  2018-02-12T04:27:29 GMT
# 4  Russian politicians fail to see funny side of ...  2017-10-18T11:59:59 GMT
#
#                            Date2  \
# 0  Published: September 28, 2018
# 1       Published: July 11, 2018
# 2      Published: April 23, 2018
# 3   Published: February 12, 2018
# 4    Published: October 18, 2017
#
#                                              Content           Author
# 0  One cannot expect a drug addict to find a job ...  M Bilal Lakhani
# 1  Ex-Alaska govern­or says she has fallen victim...            AFP .
# 2  ‘Aik Sindhi Ka Interv­iew’ takes dig at their ...      Rahul Aijaz
# 3  In a world where realit­y compet­es with satir...       Niha Dagia
# 4  A commun­ist politi­can brande­d it 'abomin­ab...         Reuters

# %%
dawn = pd.read_csv('data.csv')
dawn.head()
# Out:
#                                                  URL  \
# 0  https://www.dawn.com/news/1458127/mbbs-student...
# 1  https://www.dawn.com/news/1458129/govt-decides...
# 2  https://www.dawn.com/news/1458125/afghan-presi...
# 3  https://www.dawn.com/news/1458123/mehwish-haya...
# 4  https://www.dawn.com/news/1458118/complete-tex...
#
#                                             Headline        Date  \
# 0  MBBS student found dead in hostel room at Jams...  2019-01-17
# 1  Govt decides to remove names of Bilawal, Murad...  2019-01-17
# 2  Afghan president thanks PM Khan for Pakistan's...  2019-01-17
# 3  Mehwish Hayat acts out her musical dreams in n...  2019-01-17
# 4  Complete text of address by Justice Asif Saeed...  2019-01-17
#
#                                              Content  \
# 0  A third-year MBBS student was found shot dead ...
# 1  The federal cabinet has decided to remove the ...
# 2  Afghan President Ashraf Ghani on Thursday tele...
# 3  Director and script writer Wajahat Rauf unveil...
# 4  Complete address by Justice Asif Saeed Khosa o...
#
#                            Author
# 0           Mohammad Hussain Khan
# 1  Sanaullah Khan | Javed Hussain
# 2                  Sanaullah Khan
# 3                            None
# 4                        Dawn.com

# %%
# Convert dates to datetime object
express['Date'] =  pd.to_datetime(express['Date1'])
dawn['Date'] =  pd.to_datetime(dawn['Date'])

# %%
# dropping unecessary columns
express = express.drop(['Date1', 'Date2'], axis=1)

# %%
# Replacing None and dawn.com with dawn since no author.
dawn['Author'] = dawn['Author'].replace(to_replace=r'None', value='dawn', regex=True)
dawn['Author'] = dawn['Author'].replace(to_replace=r'Dawn.com', value='dawn', regex=True)

# %% [markdown]
# We have the following 5 categories with no author names so we will replace them with the name of the newspaper so that it is later easier to identify a source for these articles.
#   -  The Newspaper's Staff Reporter
#   - A Correspondent
#   - The Newspaper's Correspondent
#   - The Newspaper's Staff Correspondent
#   - Editorial

# %%
print(dawn['Author'].unique())
print('Number of Categories',len(dawn['Author'].unique()))
# Out:
# ['Mohammad Hussain Khan' 'Sanaullah Khan | Javed Hussain' 'Sanaullah Khan'
#  'dawn' 'dawn | Haseeb Bhatti' 'Rimmel Mohydin' 'Jamil Nagri'
#  'Bureau Report' 'Kashif Abbasi' 'Ikram Junaidi'
#  "The Newspaper's Staff Reporter" 'Naeem Sahoutara' 'Habib Khan Ghori'
#  'Hasan Mansoor' 'Behram Baloch' 'Mohammad Asghar' 'Imran Ayub'
#  'Syed Ali Shah' 'Haseeb Bhatti' 'Ali Akbar | AP' 'Rana Bilal'
#  'Sara Malkani' 'Editorial' 'Munawer Azeem' 'A Correspondent'
#  "The Newspaper's Correspondent" 'Zulfiqar Ali' 'Intikhab Hanif'
#  'Tahir Siddiqui' 'Ishaq Tanoli' 'Faiza Ilyas' 'Tariq Naqash' 'Imtiaz Ali'
#  'Tahir Naseer' 'Wajiha Khanain' 'Abdul Ghaffar' 'AP'
#  'Amir Wasim | Javed Hussain | Nadir Guramani' 'Jawaid Bokhari'
#  'Dr Niaz Murtaza' 'Amjad Iqbal' 'Hamid Asghar' 'APP'
#  "The Newspaper's Staff Correspondent" 'Zulqernain Tahir'
#  'Ghulam Hussain Khawaja' 'Dawn Report' 'Syed Irfan Raza'
#  'Monitoring Desk' 'Malik Asad' 'Syed Ali Shah | APP' 'dawn | Amir Wasim'
#  'Javed Hussain' 'Shakeel Qarar' 'Umair Javed' 'Nadir Cheema' 'AFP'
#  'Shafi Baloch' 'Abdul Moiz Jaferii' 'Khaleeq Kiani' 'Ashfaq Yusufzai'
#  'Aamir Yasin' 'Majeed Gill' 'Waseem Shamsi' 'Afshan Subohi' 'Shafiq Butt'
#  'Amir Wasim' 'Mansoor Malik' 'dawn | Qazi Hassan' 'dawn | Sirajuddin'
#  'Aamir Shafaat Khan' 'Iftikhar A. Khan' 'Wajih Ahmad Sheikh'
#  'Nasir Iqbal' 'Talqeen Zubairi' 'Naveed Siddiqui' 'Abbas Nasir'
#  'Khalid Hasnain' 'Haneen Rafi' 'Kalbe Ali' 'Masood Haider' 'Anwar Iqbal'
#  'Saleem Shahid' 'Mohammad Asghar | Azfar-ul-Ashfaque'
#  'dawn | Adnan Sheikh' 'Asha’ar Rehman' 'Shazia Hasan' 'Qamar Ahmed'
#  'Mubarak Zeb Khan' 'Fahad Chaudhry' 'Sirajuddin' 'I.A. Rehman'
#  'Khurram Husain' 'Hanif Samoon' 'Mohammad Imran | Haseeb Bhatti'
#  'Zubair Shabbir' 'Irfan-ul-Haq Malik' 'Zahid Hussain'
#  'Parvaiz Ishfaq Rana' 'Jamal Shahid' 'Imtiaz Mugheri' 'Ali Waqar | dawn'
#  'Arifa Noor' 'Xari Jalil' 'Azfar-ul-Ashfaque' 'Reuters']
# Number of Categories 106

# %%
dawn['Author'] = dawn['Author'].replace(to_replace=r'The Newspaper\'s Staff Reporter', value='dawn', regex=True)
dawn['Author'] = dawn['Author'].replace(to_replace=r'A Correspondent', value='dawn', regex=True)
dawn['Author'] = dawn['Author'].replace(to_replace=r'The Newspaper\'s Correspondent', value='dawn', regex=True)
dawn['Author'] = dawn['Author'].replace(to_replace=r'Editorial', value='dawn', regex=True)
dawn['Author'] = dawn['Author'].replace(to_replace=r'The Newspaper\'s Staff Correspondent', value='dawn', regex=True)

# %%
print('Number of Categories are:',len(dawn['Author'].unique()))
# Out:
# Number of Categories are: 101

# %%
data = pd.concat([dawn,express],axis=0,ignore_index=True,sort = False).reset_index()

# %%
# freeing memory
del[dawn,express]
data.head()
# Out:
#    index                                                URL  \
# 0      0  https://www.dawn.com/news/1458127/mbbs-student...
# 1      1  https://www.dawn.com/news/1458129/govt-decides...
# 2      2  https://www.dawn.com/news/1458125/afghan-presi...
# 3      3  https://www.dawn.com/news/1458123/mehwish-haya...
# 4      4  https://www.dawn.com/news/1458118/complete-tex...
#
#                                             Headline       Date  \
# 0  MBBS student found dead in hostel room at Jams... 2019-01-17
# 1  Govt decides to remove names of Bilawal, Murad... 2019-01-17
# 2  Afghan president thanks PM Khan for Pakistan's... 2019-01-17
# 3  Mehwish Hayat acts out her musical dreams in n... 2019-01-17
# 4  Complete text of address by Justice Asif Saeed... 2019-01-17
#
#                                              Content  \
# 0  A third-year MBBS student was found shot dead ...
# 1  The federal cabinet has decided to remove the ...
# 2  Afghan President Ashraf Ghani on Thursday tele...
# 3  Director and script writer Wajahat Rauf unveil...
# 4  Complete address by Justice Asif Saeed Khosa o...
#
#                            Author
# 0           Mohammad Hussain Khan
# 1  Sanaullah Khan | Javed Hussain
# 2                  Sanaullah Khan
# 3                            dawn
# 4                            dawn

# %%
data.tail()
# Out:
#      index                                                URL  \
# 393    393  https://tribune.com.pk/story/1412053/sneak-pea...
# 394    394  https://tribune.com.pk/story/1410222/guide-pak...
# 395    395  https://tribune.com.pk/story/1410238/tv-show-b...
# 396    396  https://tribune.com.pk/story/1375867/denying-e...
# 397    397  https://tribune.com.pk/story/1336417/not-conte...
#
#                                               Headline                Date  \
# 393           A sneak peak into the ‘CPEC Master Plan’ 2017-05-18 09:19:52
# 394  A guide for Pakistani parents: How to kill you... 2017-05-16 09:34:29
# 395  If the TV show ‘Black Mirror’ was based in Pak... 2017-05-16 06:18:20
# 396  Denying entry to Pakistani Fulbright scholar m... 2017-04-06 10:24:21
# 397  Tired of fighting Taliban at home, PM flies to... 2017-02-23 10:33:54
#
#                                                Content            Author
# 393  Karach­i will soon be called China Town under ...     Shehzad Ghias
# 394  A helpfu­l guide brough­t to you by the Pakist...  Khurram Siddiqui
# 395  The Britis­h televi­sion show deals with the r...       Rahul Aijaz
# 396  US expose­s Pakist­an’s grand plan to bring do...     Shehzad Ghias
# 397  He is not the leader we want but much like Bat...     Shehzad Ghias

# %%
# Keeping only the date part of the datetime object for consistency.
data['Date'] = data['Date'].dt.date

# %%
# Saving cleaned data
data.to_csv('articles.csv',index=False)

# %%
data = pd.read_csv('articles.csv')
data.head()
# Out:
#    index                                                URL  \
# 0      0  https://www.dawn.com/news/1458127/mbbs-student...
# 1      1  https://www.dawn.com/news/1458129/govt-decides...
# 2      2  https://www.dawn.com/news/1458125/afghan-presi...
# 3      3  https://www.dawn.com/news/1458123/mehwish-haya...
# 4      4  https://www.dawn.com/news/1458118/complete-tex...
#
#                                             Headline        Date  \
# 0  MBBS student found dead in hostel room at Jams...  2019-01-17
# 1  Govt decides to remove names of Bilawal, Murad...  2019-01-17
# 2  Afghan president thanks PM Khan for Pakistan's...  2019-01-17
# 3  Mehwish Hayat acts out her musical dreams in n...  2019-01-17
# 4  Complete text of address by Justice Asif Saeed...  2019-01-17
#
#                                              Content  \
# 0  A third-year MBBS student was found shot dead ...
# 1  The federal cabinet has decided to remove the ...
# 2  Afghan President Ashraf Ghani on Thursday tele...
# 3  Director and script writer Wajahat Rauf unveil...
# 4  Complete address by Justice Asif Saeed Khosa o...
#
#                            Author
# 0           Mohammad Hussain Khan
# 1  Sanaullah Khan | Javed Hussain
# 2                  Sanaullah Khan
# 3                            dawn
# 4                            dawn

# %%
# Number of articles for each author
Counter(data.Author)
# Out:
# Counter({'Mohammad Hussain Khan': 3,
#          'Sanaullah Khan | Javed Hussain': 1,
#          'Sanaullah Khan': 4,
#          'dawn': 179,
#          'dawn | Haseeb Bhatti': 1,
#          'Rimmel Mohydin': 1,
#          'Jamil Nagri': 2,
#          'Bureau Report': 10,
#          'Kashif Abbasi': 4,
#          'Ikram Junaidi': 8,
#          'Naeem Sahoutara': 6,
#          'Habib Khan Ghori': 3,
#          'Hasan Mansoor': 4,
#          'Behram Baloch': 1,
#          'Mohammad Asghar': 4,
#          'Imran Ayub': 2,
#          'Syed Ali Shah': 1,
#          'Haseeb Bhatti': 18,
#          'Ali Akbar | AP': 1,
#          'Rana Bilal': 8,
#          'Sara Malkani': 1,
#          'Munawer Azeem': 2,
#          'Zulfiqar Ali': 2,
#          'Intikhab Hanif': 1,
#          'Tahir Siddiqui': 4,
#          'Ishaq Tanoli': 2,
#          'Faiza Ilyas': 1,
#          'Tariq Naqash': 1,
#          'Imtiaz Ali': 5,
#          'Tahir Naseer': 1,
#          'Wajiha Khanain': 1,
#          'Abdul Ghaffar': 1,
#          'AP': 1,
#          'Amir Wasim | Javed Hussain | Nadir Guramani': 1,
#          'Jawaid Bokhari': 1,
#          'Dr Niaz Murtaza': 1,
#          'Amjad Iqbal': 1,
#          'Hamid Asghar': 1,
#          'APP': 5,
#          'Zulqernain Tahir': 1,
#          'Ghulam Hussain Khawaja': 1,
#          'Dawn Report': 2,
#          'Syed Irfan Raza': 5,
#          'Monitoring Desk': 1,
#          'Malik Asad': 5,
#          'Syed Ali Shah | APP': 1,
#          'dawn | Amir Wasim': 1,
#          'Javed Hussain': 1,
#          'Shakeel Qarar': 1,
#          'Umair Javed': 1,
#          'Nadir Cheema': 1,
#          'AFP': 5,
#          'Shafi Baloch': 1,
#          'Abdul Moiz Jaferii': 1,
#          'Khaleeq Kiani': 4,
#          'Ashfaq Yusufzai': 2,
#          'Aamir Yasin': 1,
#          'Majeed Gill': 1,
#          'Waseem Shamsi': 1,
#          'Afshan Subohi': 2,
#          'Shafiq Butt': 2,
#          'Amir Wasim': 1,
#          'Mansoor Malik': 1,
#          'dawn | Qazi Hassan': 1,
#          'dawn | Sirajuddin': 1,
#          'Aamir Shafaat Khan': 1,
#          'Iftikhar A. Khan': 1,
#          'Wajih Ahmad Sheikh': 1,
#          'Nasir Iqbal': 2,
#          'Talqeen Zubairi': 1,
#          'Naveed Siddiqui': 3,
#          'Abbas Nasir': 1,
#          'Khalid Hasnain': 3,
#          'Haneen Rafi': 1,
#          'Kalbe Ali': 1,
#          'Masood Haider': 1,
#          'Anwar Iqbal': 2,
#          'Saleem Shahid': 3,
#          'Mohammad Asghar | Azfar-ul-Ashfaque': 1,
#          'dawn | Adnan Sheikh': 1,
#          'Asha’ar Rehman': 1,
#          'Shazia Hasan': 2,
#          'Qamar Ahmed': 1,
#          'Mubarak Zeb Khan': 1,
#          'Fahad Chaudhry': 1,
#          'Sirajuddin': 1,
#          'I.A. Rehman': 1,
#          'Khurram Husain': 1,
#          'Hanif Samoon': 1,
#          'Mohammad Imran | Haseeb Bhatti': 1,
#          'Zubair Shabbir': 1,
#          'Irfan-ul-Haq Malik': 1,
#          'Zahid Hussain': 1,
#          'Parvaiz Ishfaq Rana': 1,
#          'Jamal Shahid': 1,
#          'Imtiaz Mugheri': 1,
#          'Ali Waqar | dawn': 1,
#          'Arifa Noor': 1,
#          'Xari Jalil': 1,
#          'Azfar-ul-Ashfaque': 1,
#          'Reuters': 1,
#          'M Bilal Lakhani': 1,
#          'AFP .': 1,
#          'Rahul Aijaz': 2,
#          'Niha Dagia': 1,
#          'Reuters ': 1,
#          'News Desk': 1,
#          'Shehzad Ghias': 5,
#          'AFP ': 1,
#          'Khurram Siddiqui': 1})

# %%
print('Total size of dataset is :',data.shape)
# Out:
# Total size of dataset is : (398, 6)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 6 columns):
# index       398 non-null int64
# URL         398 non-null object
# Headline    398 non-null object
# Date        398 non-null object
# Content     398 non-null object
# Author      398 non-null object
# dtypes: int64(1), object(5)
# memory usage: 18.7+ KB

# %%
print('Range of the published articles is',data.Date.min(),'-',data.Date.max())
# Out:
# Range of the published articles is 2017-02-23 - 2019-01-17

# %% [markdown]
#  - Find importance of words using headlines and content seperately

# %% [markdown]
# ### Preprocessing

# %%
def remove_non_ascii(words):
    words = [unicodedata.normalize('NFKD', word).encode('ascii', 'ignore').decode('utf-8', 'ignore') for word in words]
    return words
# The first pre-processing step which we will do is transform our tweets into lower case.
# This avoids having multiple copies of the same words
def to_lowercase(words):
    words = [word.lower() for word in words]
    return words
# Removing punctuation to reduce the amount of the training data
def remove_punctuation(words):
    words = [re.sub(r'[^\w\s]', '', word) for word in words if re.sub(r'[^\w\s]', '', word) not in '']    
    return words
# Removing numbers from data since they aren't useful in this context.
def replace_numbers(words):
    words = [re.sub(r'[^\w\s]', '', word) for word in words]
    return words
def remove_stopwords(words):
    words = [word for word in words if word not in stopwords.words('english')]
    return words

# %%
def normalize(words):
    words = remove_non_ascii(words)
    words = to_lowercase(words)
    words = remove_punctuation(words)
    words = replace_numbers(words)
    words = remove_stopwords(words)
    return words

# %%
data['tokenized_Content'] = data['Content'].apply(word_tokenize)
data['tokenized_Headline'] = data['Headline'].apply(word_tokenize)
data['tokenized_Content'] = data['tokenized_Content'].apply(normalize)
data['tokenized_Headline'] = data['tokenized_Headline'].apply(normalize)

# %%
data['tokenized_Headline'][5]
# Out:
# ['profile', 'pakistan', 'next', 'chief', 'justice', 'asif', 'saeed', 'khosa']

# %%
data.head()
# Out:
#    index                                                URL  \
# 0      0  https://www.dawn.com/news/1458127/mbbs-student...
# 1      1  https://www.dawn.com/news/1458129/govt-decides...
# 2      2  https://www.dawn.com/news/1458125/afghan-presi...
# 3      3  https://www.dawn.com/news/1458123/mehwish-haya...
# 4      4  https://www.dawn.com/news/1458118/complete-tex...
#
#                                             Headline        Date  \
# 0  MBBS student found dead in hostel room at Jams...  2019-01-17
# 1  Govt decides to remove names of Bilawal, Murad...  2019-01-17
# 2  Afghan president thanks PM Khan for Pakistan's...  2019-01-17
# 3  Mehwish Hayat acts out her musical dreams in n...  2019-01-17
# 4  Complete text of address by Justice Asif Saeed...  2019-01-17
#
#                                              Content  \
# 0  A third-year MBBS student was found shot dead ...
# 1  The federal cabinet has decided to remove the ...
# 2  Afghan President Ashraf Ghani on Thursday tele...
# 3  Director and script writer Wajahat Rauf unveil...
# 4  Complete address by Justice Asif Saeed Khosa o...
#
#                            Author  \
# 0           Mohammad Hussain Khan
# 1  Sanaullah Khan | Javed Hussain
# 2                  Sanaullah Khan
# 3                            dawn
# 4                            dawn
#
#                                    tokenized_Content  \
# 0  [thirdyear, mbbs, student, found, shot, dead, ...
# 1  [federal, cabinet, decided, remove, names, ppp...
# 2  [afghan, president, ashraf, ghani, thursday, t...
# 3  [director, script, writer, wajahat, rauf, unve...
# 4  [complete, address, justice, asif, saeed, khos...
#
#                                   tokenized_Headline
# 0  [mbbs, student, found, dead, hostel, room, jam...
# 1  [govt, decides, remove, names, bilawal, murad,...
# 2  [afghan, president, thanks, pm, khan, pakistan...
# 3  [mehwish, hayat, acts, musical, dreams, new, w...
# 4  [complete, text, address, justice, asif, saeed...

# %%
# Saving the clean data to a csv file
data.to_csv("preprocessed.csv",index=False)

# %%
data = pd.read_csv('preprocessed.csv')
data.head()
# Out:
#    index                                                URL  \
# 0      0  https://www.dawn.com/news/1458127/mbbs-student...
# 1      1  https://www.dawn.com/news/1458129/govt-decides...
# 2      2  https://www.dawn.com/news/1458125/afghan-presi...
# 3      3  https://www.dawn.com/news/1458123/mehwish-haya...
# 4      4  https://www.dawn.com/news/1458118/complete-tex...
#
#                                             Headline        Date  \
# 0  MBBS student found dead in hostel room at Jams...  2019-01-17
# 1  Govt decides to remove names of Bilawal, Murad...  2019-01-17
# 2  Afghan president thanks PM Khan for Pakistan's...  2019-01-17
# 3  Mehwish Hayat acts out her musical dreams in n...  2019-01-17
# 4  Complete text of address by Justice Asif Saeed...  2019-01-17
#
#                                              Content  \
# 0  A third-year MBBS student was found shot dead ...
# 1  The federal cabinet has decided to remove the ...
# 2  Afghan President Ashraf Ghani on Thursday tele...
# 3  Director and script writer Wajahat Rauf unveil...
# 4  Complete address by Justice Asif Saeed Khosa o...
#
#                            Author  \
# 0           Mohammad Hussain Khan
# 1  Sanaullah Khan | Javed Hussain
# 2                  Sanaullah Khan
# 3                            dawn
# 4                            dawn
#
#                                    tokenized_Content  \
# 0  ['thirdyear', 'mbbs', 'student', 'found', 'sho...
# 1  ['federal', 'cabinet', 'decided', 'remove', 'n...
# 2  ['afghan', 'president', 'ashraf', 'ghani', 'th...
# 3  ['director', 'script', 'writer', 'wajahat', 'r...
# 4  ['complete', 'address', 'justice', 'asif', 'sa...
#
#                                   tokenized_Headline
# 0  ['mbbs', 'student', 'found', 'dead', 'hostel',...
# 1  ['govt', 'decides', 'remove', 'names', 'bilawa...
# 2  ['afghan', 'president', 'thanks', 'pm', 'khan'...
# 3  ['mehwish', 'hayat', 'acts', 'musical', 'dream...
# 4  ['complete', 'text', 'address', 'justice', 'as...

# %% [markdown]
# TF: How frequently a term occurs in a document. Since every document is different in length, it is possible that a term would appear much more times in long documents than shorter ones. Thus, the term frequency is often divided by the document length (the total number of terms in the document) as a way of normalization:
#
# TF(t) = (Number of times term t appears in a document) / (Total number of terms in the document).
#
# IDF: Measures how important a term is. While computing TF, all terms are considered equally important. However it is known that certain terms, such as "is", "of", and "that", may appear a lot of times but have little importance. Thus we need to weigh down the frequent terms while scale up the rare ones, by computing the following:
#
# IDF(t) = log_e(Total number of documents / Number of documents with term t in it).
#
# - TFIDF = TF x TDF

# %%
tdf = TfidfVectorizer(stop_words='english',ngram_range=(1,2))
vectorizer = tdf.fit(data.tokenized_Content)
transformed_text = vectorizer.transform(data.tokenized_Content)

# %%
transformed_text
# Out:
# <398x99410 sparse matrix of type '<class 'numpy.float64'>'
# 	with 170486 stored elements in Compressed Sparse Row format>

# %%
transformed_text[5]
# Out:
# <1x99410 sparse matrix of type '<class 'numpy.float64'>'
# 	with 683 stored elements in Compressed Sparse Row format>

# %%
transformed_text.T[5].toarray().size
# Out:
# 398

# %%
# features created by TFIDF
feature_names = tdf.get_feature_names()
feature_names
# Out:
# ['03',
#  '03 2007',
#  '03367251214he',
#  '03367251214he said',
#  '04',
#  '04 percent',
#  '0588',
#  '0588 inches',
#  '0676',
#  '0676 maf',
#  '09pc',
#  '09pc gdp',
#  '10',
#  '10 11',
#  '10 12',
#  '10 12km',
#  '10 15',
#  '10 19',
#  '10 20',
#  '10 billion',
#  '10 days',
#  '10 detained',
#  '10 fake',
#  '10 given',
#  '10 hospitals',
#  '10 increase',
#  '10 institutes',
#  '10 land',
#  '10 lda',
#  '10 litres',
#  '10 million',
#  '10 monday',
#  '10 patients',
#  '10 people',
#  '10 police',
#  '10 policemen',
#  '10 power',
#  '10 quota',
#  '10 sonia',
#  '10 stated',
#  '10 steps',
#  '10 sunday',
#  '10 times',
#  '10 uncooperative',
#  '10 ways',
#  '10 year',
#  '10 years',
#  '10 zinda',
#  '100',
#  '100 150',
#  '100 500',
#  '100 acres',
#  '100 cent',
#  '100 cusecs',
#  '100 days',
#  '100 loan',
#  '100 megawatts',
#  '100 new',
#  '100 patients',
#  '100 posts',
#  '100 private',
#  '100 recent',
#  '100 rupees',
#  '100 totally',
#  '1000',
#  '1000 days',
#  '1000 employees',
#  '1000 pakistani',
#  '1000 people',
#  '1000 said',
#  '1000 sent',
#  '1000 women',
#  '1000 years',
#  '10000',
#  '10000 11000mw',
#  '10000 acres',
#  '10000 cameras',
#  '10000 cases',
#  '10000 hours',
#  '10000 policemen',
#  '10000 security',
#  '100041',
#  '100041 hours',
#  '1000mw',
#  '1000mw pakal',
#  '100ft',
#  '100ft 6ft',
#  '100pc',
#  '100pc coverage',
#  '100pc remarked',
#  '100th',
#  '100th test',
#  '101st',
#  '101st 200th',
#  '102',
#  '102 kanals',
#  '102bn',
#  '102bn 73bn',
#  '102nd',
#  '102nd spot',
#  '103',
#  '103 people',
#  '1030pm',
#  '1030pm published',
#  '103pc',
#  '103pc 27pc',
#  '1049',
#  '1049 sbp',
#  '104pc',
#  '104pc adults',
#  '104th',
#  '104th spot',
#  '108',
#  '108 days',
#  '109',
#  '109 corruption',
#  '109 pending',
#  '1097bn',
#  '1097bn corresponding',
#  '109th',
#  '109th day',
#  '10a',
#  '10a constitution',
#  '10am',
#  '10am 6pm',
#  '10bn',
#  '10bn 12bn',
#  '10bn investment',
#  '10bn month',
#  '10bn plus',
#  '10day',
#  '10day paternity',
#  '10day span',
#  '10kanal',
#  '10kanal land',
#  '10km',
#  '10km jog',
#  '10maf',
#  '10maf 2maf',
#  '10member',
#  '10member team',
#  '10mw',
#  '10mw hydel',
#  '10pc',
#  '10pc thinness',
#  '10pm',
#  '10pm mr',
#  '10point',
#  '10point action',
#  '10th',
#  '10th 2019',
#  '10th grader',
#  '10th sikh',
#  '10year',
#  '10year imprisonment',
#  '10yearold',
#  '10yearold amal',
#  '11',
#  '11 2016',
#  '11 2018',
#  '11 announced',
#  '11 armed',
#  '11 attacks',
#  '11 despite',
#  '11 document',
#  '11 drug',
#  '11 explaining',
#  '11 government',
#  '11 heritage',
#  '11 million',
#  '11 missing',
#  '11 months',
#  '11 new',
#  '11 reporting',
#  '11 sectarian',
#  '11 senior',
#  '11 year',
#  '11000mw',
#  '11000mw generation',
#  '1112',
#  '1112 islamabad',
#  '1113',
#  '1113 beach',
#  '1115',
#  '1115 people',
#  '1121bn',
#  '1121bn 1097bn',
#  '1122',
#  '1122 officials',
#  '1122 sngpl',
#  '1122 sources',
#  '1123',
#  '1123 million',
#  '1123pc',
#  '1123pc overweightobesity',
#  '1130pm',
#  '1130pm tuesday',
#  '114',
#  '114 injured',
#  '115',
#  '115 grade',
#  '115th',
#  '115th meeting',
#  '1167',
#  '1167 transactions',
#  '1185',
#  '1185 illegal',
#  '119',
#  '119 people',
#  '11am',
#  '11am dawnnewstv',
#  '11am earlier',
#  '11am tuesday',
#  '11daylong',
#  '11daylong festival',
#  '11pc',
#  '11pc unfortunately',
#  '11th',
#  '11th 2019',
#  '11th plan',
#  '12',
#  '12 13',
#  '12 15',
#  '12 2018',
#  '12 according',
#  '12 arrest',
#  '12 billion',
#  '12 court',
#  '12 different',
#  '12 districts',
#  '12 fail',
#  '12 news',
#  '12 people',
#  '12 regarding',
#  '12 request',
#  '12 sales',
#  '12 years',
#  '120',
#  '120 illegal',
#  '1200',
#  '1200 people',
#  '12000',
#  '12000 gallons',
#  '12000 people',
#  '12000 procedures',
#  '1208',
#  '1208 external',
#  '120mmcfd',
#  '120mmcfd half',
#  '120mmcfd sngpl',
#  '1211',
#  '1211 pakistani',
#  '1215',
#  '1215 1403',
#  '12156',
#  '12156 acres',
#  '12156 swelled',
#  '12175',
#  '12175 people',
#  '12175 teachers',
#  '1219',
#  '1219 inquires',
#  '1230pm',
#  '1230pm 1030pm',
#  '1245',
#  '1245 ibos',
#  '1245 intelligencebased',
#  '1295',
#  '1295 fia',
#  '129m',
#  '129m period',
#  '12bn',
#  '12bn adding',
#  '12km',
#  '12km department',
#  '12member',
#  '12member commission',
#  '12pc',
#  '12pc according',
#  '12pc girls',
#  '12pc uae',
#  '12th',
#  '12th 2019',
#  '12th century',
#  '12th fiveyear',
#  '12th plan',
#  '13',
#  '13 14',
#  '13 2013',
#  '13 2017',
#  '13 2018',
#  '13 anwar',
#  '13 arrested',
#  '13 called',
#  '13 carried',
#  '13 cdr',
#  '13 game',
#  '13 housing',
#  '13 lahore',
#  '13 long',
#  '13 men',
#  '13 places',
#  '13 police',
#  '13 tenants',
#  '13 year',
#  '13 years',
#  '130',
#  '130 cases',
#  '13000',
#  '13000 acres',
#  '131',
#  '131 schoolchildren',
#  '132',
#  '132 assembly',
#  '132 leaving',
#  '132 punjab',
#  '1320megawatt',
#  '1320megawatt rahimyar',
#  '1334',
#  '1334 link',
#  '135',
#  '135 billion',
#  '1365',
#  '1365 properties',
#  '1380000',
#  '1380000 patients',
#  '139bn',
#  '139bn 2bn',
#  '13pc',
#  '13pc adolescents',
#  '13pc timely',
#  '13th',
#  '13th 2019',
#  '14',
#  '14 15',
#  '14 25',
#  '14 absconding',
#  '14 appeal',
#  '14 defending',
#  '14 foreign',
#  '14 ii',
#  '14 islamabad',
#  '14 monday',
#  '14 read',
#  '14 said',
#  '14 sisters',
#  '14 today',
#  '14 vacant',
#  '14 vc',
#  '14 wednesday',
#  '14 workers',
#  '14 year',
#  '14 years',
#  '140',
#  '140 characters',
#  '140 million',
#  '1400',
#  '1400 years',
#  '140000',
#  '140000 square',
#  '1403',
#  '1403 dollar',
#  '141',
#  '141 ingos',
#  '142',
#  '142 97',
#  '1430',
#  '1430 2018',
#  '14398',
#  '14398 acres',
#  '143kmlong',
#  '143kmlong railway',
#  '144',
#  '144 ban',
#  '144 crpc',
#  '14431509',
#  '14431509 developed',
#  '145245',
#  '145245 acres',
#  '145245 retrieved',
#  '1462pc',
#  '1462pc balochistan',
#  '1469m',
#  '1469m tonnes',
#  '147',
#  '147 testimonies',
#  '147000',
#  '147000 animals',
#  '149pc',
#  '149pc transport',
#  '14day',
#  '14day physical',
#  '14day remand',
#  '14pc',
#  '14pc wholesale',
#  '14th',
#  '14th 2019',
#  '14yearold',
#  '14yearold boy',
#  '14yearold hina',
#  '15',
#  '15 16',
#  '15 19',
#  '15 1972',
#  '15 2019',
#  '15 25',
#  '15 25pc',
#  '15 49',
#  '15 9am',
#  '15 builtupproperties',
#  '15 cent',
#  '15 central',
#  '15 court',
#  '15 days',
#  '15 directed',
#  '15 ensure',
#  '15 final',
#  '15 issued',
#  '15 litre',
#  '15 million',
#  '15 minutes',
#  '15 monday',
#  '15 mother',
#  '15 paramilitary',
#  '15 personal',
#  '15 police',
#  '15 recommendations',
#  '15 resumed',
#  '15 said',
#  '15 saturday',
#  '15 sought',
#  '15 suspend',
#  '15 today',
#  '15 visits',
#  '15 years',
#  '150',
#  '150 employees',
#  '150 men',
#  '150 people',
#  '150 years',
#  '1500',
#  '1500 2000',
#  '1500 fistula',
#  '15000',
#  '15000 employees',
#  '15000 posts',
#  '150000',
#  '150000 patients',
#  '150seat',
#  '150seat auditorium',
#  '1521',
#  '1521 bhai',
#  '153',
#  '153 sindh',
#  '1539',
#  '1539 complaints',
#  '154',
#  '154 constitution',
#  '154 despite',
#  '155',
#  '155 cent',
#  '155 police',
#  '155pc',
#  '155pc 7796tr',
#  '157',
#  '157 people',
#  '158',
#  '158 constitution',
#  '159bn',
#  '159bn months',
#  '15bn',
#  '15bn international',
#  '15day',
#  '15day physical',
#  '15pc',
#  '15pc development',
#  '15pc increase',
#  '15pc says',
#  '15pc sc',
#  '15pc vs',
#  '15th',
#  '15th 2019',
#  '15th century',
#  '15yearsold',
#  '15yearsold muhammad',
#  '16',
#  '16 17',
#  '16 1992',
#  '16 2013',
#  '16 2014',
#  '16 2018',
#  '16 9am',
#  '16 federal',
#  '16 grade',
#  '16 grid',
#  '16 hearing',
#  '16 injured',
#  '16 items',
#  '16 maintenance',
#  '16 million',
#  '16 mother',
#  '16 pilots',
#  '16 said',
#  '16 years',
#  '160',
#  '160 3a',
#  '160 constitution',
#  '16000',
#  '16000 acres',
#  '160639',
#  '160639 million',
#  '161',
#  '161 criminal',
#  '161 crpc',
#  '161m',
#  '161m fy17',
#  '16200',
#  '16200 acres',
#  '163',
#  '163 aq',
#  '1644',
#  '1644 acres',
#  '165pc',
#  '165pc manufacturing',
#  '1664',
#  '1664 acres',
#  '167',
#  '167 people',
#  '168bn',
#  '168bn corresponding',
#  '16kg',
#  '16kg hashish',
#  '16m',
#  '16m heads',
#  '16monthold',
#  '16monthold girl',
#  '16pc',
#  '16pc effective',
#  '16th',
#  '16th 2019',
#  '16th pashto',
#  '17',
#  '17 1969',
#  '17 2019',
#  '17 chillers',
#  '17 contractors',
#  '17 discount',
#  '17 east',
#  '17 employee',
#  '17 families',
#  '17 feel',
#  '17 final',
#  '17 formation',
#  '17 issue',
#  '17 jaffer',
#  '17 million',
#  '17 published',
#  '17 reconstituting',
#  '17 remain',
#  '17 ssts',
#  '17 wins',
#  '170',
#  '170 accused',
#  '1700',
#  '1700 workers',
#  '172',
#  '172 158',
#  '172 individuals',
#  '172 names',
#  '172 people',
#  '172 persons',
#  '172 suspects',
#  '1723',
#  '1723 2018',
#  '173',
#  '173 crpc',
#  '1750',
#  '1750 dock',
#  '1751',
#  '1751 dock',
#  '177bn',
#  '177bn julydecember',
#  '178',
#  '178 1000',
#  '17member',
#  '17member bench',
#  '17member pmdc',
#  '17th',
#  '17th 2019',
#  '17th century',
#  '17year',
#  '17year war',
#  '17yearold',
#  '17yearold brother',
#  '17yearold war',
#  '18',
#  '18 1954',
#  '18 2010',
#  '18 22',
#  '18 29yearolds',
#  '18 8pc',
#  '18 born',
#  '18 cases',
#  '18 cheques',
#  '18 committees',
#  '18 especially',
#  '18 incident',
#  '18 increasing',
#  '18 ingos',
#  '18 legally',
#  '18 members',
#  '18 million',
#  '18 months',
#  '18 mr',
#  '18 new',
#  '18 november',
#  '18 occurs',
#  '18 official',
#  '18 politicians',
#  '18 rupees',
#  '18 times',
#  '18 undeclared',
#  '18 warned',
#  '18 year',
#  '18 years',
#  '1800',
#  '1800 recruitments',
#  '18000',
#  '18000 workers',
#  '182142',
#  '182142 tonnes',
#  '18336',
#  '18336 acres',
#  '184',
#  '184 constitution',
#  '184 doubts',
#  '184 limitations',
#  '184 original',
#  '185',
#  '185 destinations',
#  '185 years',
#  '1855',
#  '1855 sought',
#  '1859',
#  '1859 cartridges',
#  '1859 said',
#  '1869',
#  '1869 combing',
#  '186pc',
#  '186pc according',
#  '187',
#  '187 destinations',
#  '188',
#  '188 destinations',
#  '189',
#  '189 destinations',
#  '189pc',
#  '189pc gdp',
#  '18pc',
#  '18pc respectively',
#  '18th',
#  '18th amendment',
#  '18th constitution',
#  '18th constitutional',
#  '19',
#  '19 2012',
#  '19 2018',
#  '19 child',
#  '19 courtformed',
#  '19 hearing',
#  '19 judgement',
#  '19 million',
#  '19 paragon',
#  '19 published',
#  '19 use',
#  '19 years',
#  '190',
#  '190 countries',
#  '190 destinations',
#  '1908',
#  '1908 read',
#  '1912',
#  '1912 cogla',
#  '1920s',
#  '1920s 1930s',
#  '1930s',
#  '1930s opposition',
#  '1947',
#  '1947 fayaz',
#  '1947 meant',
#  '1947 punjabis',
#  '1948',
#  '1948 respected',
#  '1949',
#  '1949 destroyed',
#  '1949 revolution',
#  '1950s',
#  '1950s according',
#  '1950s early',
#  '1950s remarked',
#  '1953',
#  '1953 russia',
#  '1954',
#  '1954 dera',
#  '1954 joined',
#  '1954 lahore',
#  '1954 mohajir',
#  '1960',
#  '1960 civic',
#  '1960 indus',
#  '1960 ordinance',
#  '1960 sold',
#  '1960s',
#  '1960s traced',
#  '1960s vehemently',
#  '1961',
#  '1961 dissolution',
#  '1965',
#  '1965 war',
#  '1968',
#  '1968 antiayub',
#  '1969',
#  '1969 1986',
#  '1969 edition',
#  '1969 gen',
#  '1969 mm',
#  '1969 novel',
#  '1969 scmandated',
#  '1970',
#  '1970 1972',
#  '1970 election',
#  '1970 united',
#  '1970s',
#  '1970s 1000',
#  '1970s divide',
#  '1970s mr',
#  '1970s took',
#  '1971',
#  '1971 conflict',
#  '1971 diplomats',
#  '1971 war',
#  '1972',
#  '1972 edition',
#  '1972 gave',
#  '1972 pppled',
#  '1972 riots',
#  '1973',
#  '1973 amendments',
#  '1973 constitution',
#  '1974',
#  '1974 karachi',
#  '1977',
#  '1977 movement',
#  '197788',
#  '197788 repeated',
#  '1978',
#  '1978 achieved',
#  '1978 karachi',
#  '1978 provide',
#  '1978 read',
#  '1979',
#  '1979 supreme',
#  '197980',
#  '197980 joined',
#  '197bn',
#  '197bn year',
#  '1980',
#  '1980 days',
#  '1980 enrolled',
#  '1980 factory',
#  '1980s',
#  '1980s according',
#  '1980s mqm',
#  '1980s residents',
#  '1980s target',
#  '1981',
#  '1981 35',
#  '1981 apmso',
#  '1981 cda',
#  '1981 deserve',
#  '1981 dispute',
#  '1981 possession',
#  '1982',
#  '1982 advocate',
#  '1982 orders',
#  '1983',
#  '1983 organisation',
#  '1984',
#  '1984 procurement',
#  '1984 published',
#  '1985',
#  '1985 advocate',
#  '1986',
#  '1986 chosen',
#  '1986 half',
#  '1986 mqmp',
#  '1986 mr',
#  '1986 mustafa',
#  '1986 new',
#  '1986 patwaris',
#  '1986 sharif',
#  '1986 worst',
#  '1988',
#  '1988 attained',
#  '199',
#  '199 article',
#  '1990',
#  '1990 elections',
#  '1990 general',
#  '1990 joint',
#  '1990 polls',
#  '1990 restored',
#  '1990s',
#  '1990s case',
#  '1990s passenger',
#  '1990s summoned',
#  '1991',
#  '1991 accord',
#  '1991 explore',
#  '1991 hamza',
#  '1992',
#  '1992 agreement',
#  '1992 bilateral',
#  '1992 code',
#  '1992 shown',
#  '1992 world',
#  '1993',
#  '1993 gun',
#  '1993 province',
#  '1993 purpose',
#  '1994',
#  '1994 elevated',
#  '1994 isi',
#  '1994 tariff',
#  '199495',
#  '199495 soundly',
#  '1995',
#  '1995 areas',
#  '1995 functioning',
#  '1995 years',
#  '1996',
#  '1996 asghar',
#  '1997',
#  '1997 2012',
#  '1997 considering',
#  '1997 ferozabad',
#  '1997 gulshanimaymar',
#  '1997 lahore',
#  '1997 member',
#  '1997 sentenced',
#  '1997 subsequently',
#  '1997 university',
#  '1998',
#  '1998 deposed',
#  '1998 supreme',
#  '1999',
#  '1999 90pc',
#  '1999 high',
#  '1999 plan',
#  '1999 special',
#  '19andahalf',
#  '19andahalf years',
#  '1pc',
#  '1pc occupations',
#  '20',
#  '20 15',
#  '20 2017',
#  '20 2018',
#  '20 24',
#  '20 acres',
#  '20 cent',
#  '20 chance',
#  '20 committees',
#  '20 days',
#  '20 enable',
#  '20 individuals',
#  '20 kilometres',
#  '20 million',
#  '20 names',
#  '20 new',
#  '20 personnel',
#  '20 putting',
#  '20 quetta',
#  '20 rupees',
#  '20 ships',
#  '20 times',
#  '20 welltrained',
#  '20 year',
#  '20 years',
#  '200',
#  '200 2600',
#  '200 alright',
#  '200 cases',
#  '200 outside',
#  '200 privately',
#  '200 quarters',
#  '200 terrorists',
#  '200 women',
#  '200 years',
#  '2000',
#  '2000 acres',
#  '2000 automatically',
#  '2000 da',
#  '2000 grammes',
#  '2000 province',
#  '2000 said',
#  '2000 students',
#  '2000 translation',
#  '200000',
#  '200000 new',
#  '2000s',
#  '2000s book',
#  '2001',
#  '2001 citizen',
#  '2001 curbed',
#  '2001 government',
#  '2001 killing',
#  '2001 subsequently',
#  '2002',
#  '2002 place',
#  '2002 said',
#  '2003',
#  '2003 khizar',
#  '2003 killing',
#  '2003 know',
#  '2003 shooting',
#  '2003 spent',
#  '2004',
#  '2004 chartered',
#  '2004 construction',
#  '2004 fine',
#  '2004 instead',
#  '2004model',
#  '2004model vehicles',
#  '2005',
#  '2005 kpt',
#  '2006',
#  '2006 2010',
#  '2006 bringing',
#  '2006 judgment',
#  '2006 ministry',
#  '200615',
#  '200615 period',
#  '2007',
#  '2007 2008',
#  '2007 age',
#  '2007 meeting',
#  '2007 originals',
#  '2007 project',
#  '2007 provide',
#  '2007 reduction',
#  '2007 restored',
#  '2007 revised',
#  '2008',
#  '2008 2013',
#  '2008 agreement',
#  '2008 elevated',
#  '2008 general',
#  '2008 include',
#  '2008 innocent',
#  '2008 jail',
#  '2008 petition',
#  '2008 ppp',
#  '2008 project',
#  '200809',
#  '200809 said',
#  '2009',
#  '2009 2013',
#  '2009 aftermath',
#  '2009 completed',
#  '2009 introduced',
#  '2009 khizar',
#  '2009 killing',
#  '2009 present',
#  '2009 stated',
#  '2009 zahra',
#  '20092013',
#  '20092013 subsequently',
#  '200th',
#  '200th worker',
#  '2010',
#  '2010 2016',
#  '2010 2018',
#  '2010 approved',
#  '2010 extended',
#  '2010 floods',
#  '2010 high',
#  '2010 jail',
#  '2010 judge',
#  '2010 justice',
#  '2010 ppp',
#  '2010 private',
#  '2010 teacher',
#  '2011',
#  '2011 2020',
#  '2011 al',
#  '2011 allegations',
#  '2011 biography',
#  '2011 essay',
#  '2011 shot',
#  ...]

# %%
def tfidf_scores(feature_names):
    "Returns dictionary with term names and total tfidf scores for all terms in corpus"
# We take transpose so that for each word we can see the tfidf score acorss each row.
#For total tfidf of one word we add all the values of that word across all the documents.
#array is of size 398(number of rows in data)
# For each term we are adding its 398 matrix
    term_dict = {}
    for i,term in enumerate(feature_names):
        term_name = feature_names[i]
        term_dict[term_name] = np.sum(transformed_text.T[i].toarray())   
    return term_dict

# %%
term_dict = tfidf_scores(feature_names)

# %%
print ('Number of terms/keys are: ',len(term_dict.keys()))
# Out:
# Number of terms/keys are:  99410

# %%
sort_index = np.argsort(list(term_dict.values()))[::-1]

# %%
def sorted_tfidf_scores(term_dict):
# [::-1] Gives the index in descending order.  
    sort_index = np.argsort(list(term_dict.values()))[::-1]
    terms = np.array(list(term_dict.keys()))
    scores = np.array(list(term_dict.values()))
    terms = terms[sort_index]
    scores = scores[sort_index]
    return terms, scores

# %%
terms, scores = sorted_tfidf_scores(term_dict)

# %%
"Returns plot accordng to importance of top N terms/words"
def plot(scores,terms, words = 50):
    fig = plt.figure(figsize = (20, 20))
    override = {'fontsize': 'large'}
    sb.barplot(x = scores[:words], y = terms[:words]);
    plt.title("Importance of Top {0} Terms".format(words),fontsize = 40)
    plt.xlabel("TFIDF Score",fontsize = 30)

# %%
plot(scores, terms, words = 50)
